# %% [markdown]
# Задание 1
# На основании датасета для каждого покупателя получите:
# предпочитаемый метод оплаты;
# общие траты;
# количество денег, потраченных на дополнительные услуги и аксессуары.

# %%
import pandas as pd

df = pd.read_csv("Electronic_sales_Sep2023-Sep2024.csv", sep=",")
#df.head(5)

df
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 0             1000   53    Male             No   Smartphone  SKU1004       2
# 1             1000   53    Male             No       Tablet  SKU1002       3
# 2             1002   41    Male             No       Laptop  SKU1005       3
# 3             1002   41    Male            Yes   Smartphone  SKU1004       2
# 4             1003   75    Male            Yes   Smartphone  SKU1001       5
# ...            ...  ...     ...            ...          ...      ...     ...
# 19995        19996   27  Female             No   Smartphone   SMP234       4
# 19996        19996   27  Female            Yes       Laptop   LTP123       4
# 19997        19996   27  Female             No   Headphones   HDP456       4
# 19998        19997   27    Male             No   Headphones   HDP456       1
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Paypal', 'Cash', 'Debit Card', 'Bank Transfer',
#        'PayPal'], dtype=object)

# %%
#предпочитаемый метод оплаты; 

pref_pay = df.groupby('Customer ID')['Payment Method'].agg(lambda x: x.mode()[0])

pref_pay = pd.DataFrame(pref_pay)

pref_pay
# Out:
#             Payment Method
# Customer ID
# 1000           Credit Card
# 1002                  Cash
# 1003                  Cash
# 1004           Credit Card
# 1005            Debit Card
# ...                    ...
# 19994        Bank Transfer
# 19995          Credit Card
# 19996        Bank Transfer
# 19997        Bank Transfer
# 19998        Bank Transfer
#
# [12136 rows x 1 columns]

# %%
df_orders = df[ df['Order Status'] == 'Completed' ]
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 1             1000   53    Male             No       Tablet  SKU1002       3
# 2             1002   41    Male             No       Laptop  SKU1005       3
# 3             1002   41    Male            Yes   Smartphone  SKU1004       2
# 4             1003   75    Male            Yes   Smartphone  SKU1001       5
# 5             1004   41  Female             No   Smartphone  SKU1001       5
# ...            ...  ...     ...            ...          ...      ...     ...
# 19991        19995   69  Female            Yes       Laptop   LTP123       3
# 19994        19996   27  Female             No   Smartphone   SMP234       5
# 19995        19996   27  Female             No   Smartphone   SMP234       4
# 19997        19996   27  Female             No   Headphones   HDP456       4
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...

# %%
#общие траты;

sum_total_price = df_orders.groupby('Customer ID').agg({
    'Total Price': 'sum'
}).round(2)

sum_total_price
# Out:
#              Total Price
# Customer ID
# 1000              741.09
# 1002             5020.60
# 1003               41.50
# 1004               83.00
# 1005            11779.11
# ...                  ...
# 19990            9117.44
# 19991           12368.06
# 19995            5394.56
# 19996           12063.02
# 19998             674.32
#
# [9466 rows x 1 columns]

# %%
# количество денег, потраченных на дополнительные услуги и аксессуары

sum_add_price = df_orders.groupby('Customer ID').agg({
    'Add-on Total': 'sum'
}).round(2)

sum_add_price
# Out:
#              Add-on Total
# Customer ID
# 1000                26.09
# 1002                60.16
# 1003                35.56
# 1004                65.78
# 1005                75.33
# ...                   ...
# 19990              113.56
# 19991                0.00
# 19995                0.00
# 19996              198.98
# 19998                0.00
#
# [9466 rows x 1 columns]

# %% [markdown]
# Задание 2
# 1. На основании датасета получите доход:
# по каждому методу доставки,
# по каждому типу продукта,
# по дополнительным услугам за каждый месяц,
# по дополнительным услугам за каждый квартал.
# 2. Отобразите полученные данные на графике.

# %%
#На основании датасета получите доход:
#по каждому методу доставки

ship_type = df_orders.groupby('Shipping Type').agg({
        'Total Price': 'sum'
    })

ship_type
# Out:
#                Total Price
# Shipping Type
# Expedited       8430385.58
# Express         5632093.35
# Overnight       5887722.52
# Same Day        8292376.50
# Standard       14387037.62

# %%
#2. Отобразите полученные данные на графике.

import matplotlib.pyplot as plt

ship_type.plot()
# Out:
# <AxesSubplot:xlabel='Shipping Type'>

# %%
#На основании датасета получите доход:
#по каждому типу продукта

prod_type = df_orders.groupby('Product Type').agg({
        'Total Price': 'sum'
    })

prod_type
# Out:
#               Total Price
# Product Type
# Headphones     2734651.00
# Laptop         8365905.25
# Smartphone    14407835.84
# Smartwatch     9398591.23
# Tablet         7722632.25

# %%
prod_type.plot()
# Out:
# <AxesSubplot:xlabel='Product Type'>

# %%
#На основании датасета получите доход:
#по дополнительным услугам за каждый месяц
df['Mounth'] = pd.to_datetime(df['Purchase Date']).dt.month

mnth = df_orders.groupby('Mounth').agg({
        'Add-on Total': 'sum'
    })

mnth
# Out:
#         Add-on Total
# Mounth
# 1           93254.95
# 2           80253.72
# 3           84713.93
# 4           82294.06
# 5           89374.18
# 6           84648.60
# 7           88811.55
# 8           87861.11
# 9           71026.37
# 10          26153.21
# 11          24453.33
# 12          22750.23

# %%
mnth.plot()
# Out:
# <AxesSubplot:xlabel='Mounth'>

# %%
#На основании датасета получите доход:
#по дополнительным услугам за каждый квартал


df['Quarter'] = pd.to_datetime(df['Purchase Date']).dt.quarter

qrtr = df_orders.groupby('Quarter').agg({
        'Add-on Total': 'sum'
    })

qrtr
# Out:
#          Add-on Total
# Quarter
# 1           258222.60
# 2           256316.84
# 3           247699.03
# 4            73356.77

# %%
qrtr.plot()
# Out:
# <AxesSubplot:xlabel='Quarter'>
